# %%
# !pip install ccxt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 23.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.5/75.5 kB 2.5 MB/s eta 0:00:00
# ...

# %%
import ccxt
import pandas as pd
from datetime import datetime

# %%
binance = ccxt.binance()
y = 'ApiKey'
z = 'SecretKey'

# %%
binance = ccxt.binance({
    'apiKey':y,
    'secret':z
})

# %%
get_market = binance.load_markets()

# %%
binance.markets['DOGE/USDT']
# Out:
# {'id': 'DOGEUSDT',
#  'symbol': 'DOGE/USDT',
#  'base': 'DOGE',
#  'quote': 'USDT',
#  'baseId': 'DOGE',
#  'quoteId': 'USDT',
#  'active': True,
#  'type': 'spot',
#  'linear': None,
#  'inverse': None,
#  'spot': True,
#  'swap': False,
#  'future': False,
#  'option': False,
#  'margin': True,
#  'contract': False,
#  'contractSize': None,
#  'expiry': None,
#  'expiryDatetime': None,
#  'optionType': None,
#  'strike': None,
#  'settle': None,
#  'settleId': None,
#  'precision': {'amount': 0, 'price': 5, 'base': 8, 'quote': 8},
#  'limits': {'amount': {'min': 1.0, 'max': 9000000.0},
#   'price': {'min': 1e-05, 'max': 1000.0},
#   'cost': {'min': 10.0, 'max': None},
#   'leverage': {'min': None, 'max': None},
#   'market': {'min': 0.0, 'max': 43527074.21111111}},
#  'info': {'symbol': 'DOGEUSDT',
#   'status': 'TRADING',
#   'baseAsset': 'DOGE',
#   'baseAssetPrecision': '8',
#   'quoteAsset': 'USDT',
#   'quotePrecision': '8',
#   'quoteAssetPrecision': '8',
# ...

# %%
bars = binance.fetch_ohlcv('BTC/USDT',timeframe='1h',limit=100)
bars
# Out:
# [[1672844400000, 16830.12, 16858.51, 16765.3, 16854.05, 14251.27171],
#  [1672848000000, 16853.55, 16897.0, 16829.0, 16858.85, 10314.19057],
#  [1672851600000, 16858.85, 16940.0, 16849.5, 16893.24, 11064.92581],
#  [1672855200000, 16892.98, 16985.91, 16872.07, 16948.04, 11575.12283],
#  [1672858800000, 16948.04, 16991.87, 16787.85, 16842.36, 19122.11255],
#  [1672862400000, 16842.32, 16852.23, 16777.0, 16806.49, 10533.90467],
#  [1672866000000, 16806.49, 16832.73, 16793.73, 16826.81, 4532.62963],
#  [1672869600000, 16827.21, 16853.71, 16814.93, 16826.68, 4037.94925],
#  [1672873200000, 16826.72, 16869.56, 16815.54, 16850.36, 5842.8281],
#  [1672876800000, 16850.36, 16878.18, 16827.24, 16828.45, 6623.10938],
#  [1672880400000, 16828.09, 16849.99, 16807.72, 16832.9, 5556.45206],
#  [1672884000000, 16833.37, 16844.44, 16823.3, 16836.8, 4543.82321],
#  [1672887600000, 16836.8, 16838.57, 16818.86, 16827.71, 5040.38256],
# ...

# %%
df = pd.DataFrame(bars,columns=['timestamp','open','high','low','close','volume'])
df
# Out:
#         timestamp      open      high       low     close       volume
# 0   1672844400000  16830.12  16858.51  16765.30  16854.05  14251.27171
# 1   1672848000000  16853.55  16897.00  16829.00  16858.85  10314.19057
# 2   1672851600000  16858.85  16940.00  16849.50  16893.24  11064.92581
# 3   1672855200000  16892.98  16985.91  16872.07  16948.04  11575.12283
# 4   1672858800000  16948.04  16991.87  16787.85  16842.36  19122.11255
# ..            ...       ...       ...       ...       ...          ...
# 95  1673186400000  16933.32  16954.30  16931.25  16952.44   5570.28633
# 96  1673190000000  16952.44  17019.79  16938.00  17000.43   9212.24098
# 97  1673193600000  17000.43  17022.08  16916.10  16936.87  10618.32869
# 98  1673197200000  16936.87  16952.03  16920.30  16928.50   5335.04620
# 99  1673200800000  16928.89  16934.70  16919.94  16931.67   2102.92910
#
# [100 rows x 6 columns]

# %%
df['timestamp']=pd.to_datetime(df['timestamp'],unit='ms')

# %%
df
# Out:
#              timestamp      open      high       low     close       volume
# 0  2023-01-04 15:00:00  16830.12  16858.51  16765.30  16854.05  14251.27171
# 1  2023-01-04 16:00:00  16853.55  16897.00  16829.00  16858.85  10314.19057
# 2  2023-01-04 17:00:00  16858.85  16940.00  16849.50  16893.24  11064.92581
# 3  2023-01-04 18:00:00  16892.98  16985.91  16872.07  16948.04  11575.12283
# 4  2023-01-04 19:00:00  16948.04  16991.87  16787.85  16842.36  19122.11255
# ..                 ...       ...       ...       ...       ...          ...
# 95 2023-01-08 14:00:00  16933.32  16954.30  16931.25  16952.44   5570.28633
# 96 2023-01-08 15:00:00  16952.44  17019.79  16938.00  17000.43   9212.24098
# 97 2023-01-08 16:00:00  17000.43  17022.08  16916.10  16936.87  10618.32869
# 98 2023-01-08 17:00:00  16936.87  16952.03  16920.30  16928.50   5335.04620
# 99 2023-01-08 18:00:00  16928.89  16934.70  16919.94  16931.67   2102.92910
#
# [100 rows x 6 columns]

# %%
response = binance.create_order('BNB/BUSD','limit','buy',0.05,'240')
# it work

# %%
my_open_orders = binance.fetch_open_orders('BNB/BUSD')
my_open_orders
# Out:
# [{'info': {'symbol': 'BNBBUSD',
#    'orderId': '1529158778',
#    'orderListId': '-1',
#    'clientOrderId': 'x-R4BD3S826102f42484c219377763d2',
#    'price': '240.00000000',
#    'origQty': '0.05000000',
#    'executedQty': '0.00000000',
#    'cummulativeQuoteQty': '0.00000000',
#    'status': 'NEW',
#    'timeInForce': 'GTC',
#    'type': 'LIMIT',
#    'side': 'BUY',
#    'stopPrice': '0.00000000',
#    'icebergQty': '0.00000000',
#    'time': '1673203093763',
#    'updateTime': '1673203093763',
#    'isWorking': True,
#    'workingTime': '1673203093763',
#    'origQuoteOrderQty': '0.00000000',
#    'selfTradePreventionMode': 'NONE'},
#   'id': '1529158778',
#   'clientOrderId': 'x-R4BD3S826102f42484c219377763d2',
#   'timestamp': 1673203093763,
#   'datetime': '2023-01-08T18:38:13.763Z',
#   'lastTradeTimestamp': None,
#   'symbol': 'BNB/BUSD',
#   'type': 'limit',
#   'timeInForce': 'GTC',
#   'postOnly': False,
#   'reduceOnly': None,
#   'side': 'buy',
#   'price': 240.0,
# ...

# %%
resp = binance.create_order('BNB/BUSD','market','buy',0.05)

# %%
test = pd.DataFrame(binance.fetch_open_orders('BNB/BUSD'))

# %%
test
# Out:
#                                                 info          id  \
# 0  {'symbol': 'BNBBUSD', 'orderId': '1529158778',...  1529158778
#
#                       clientOrderId      timestamp                  datetime  \
# 0  x-R4BD3S826102f42484c219377763d2  1673203093763  2023-01-08T18:38:13.763Z
#
#   lastTradeTimestamp    symbol   type timeInForce  postOnly  ... triggerPrice  \
# 0               None  BNB/BUSD  limit         GTC     False  ...         None
#
#   amount  cost average  filled  remaining status   fee  trades fees
# 0   0.05   0.0    None     0.0       0.05   open  None      []   []
#
# [1 rows x 23 columns]
