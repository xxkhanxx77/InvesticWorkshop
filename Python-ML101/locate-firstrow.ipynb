# %%
import yfinance as yf
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = yf.download('BBL.BK KBANK.BK SCB.BK BAY.BK TTB.BK KKP.BK TISCO.BK SAWAD.BK MTC.BK TIDLOR.BK AMANAH.BK AEONTS.BK ASK.BK CHAYO.BK JMT.BK KTC.BK MICRO.BK MTC.BK NCAP.BK S11.BK SAK.BK THANI.BK Tk.BK'
                  ,start='2018-01-01',end='2022-10-14',period='1d')
# Out:
# [*********************100%***********************]  22 of 22 completed

# %%
df=data['Adj Close']

# %%
df
# Out:
#              AEONTS.BK  AMANAH.BK     ASK.BK     BAY.BK      BBL.BK  CHAYO.BK  \
# Date
# 2018-01-03   91.102783   1.300324  17.726862  34.921165  173.468857       NaN
# 2018-01-04   91.102783   1.323272  17.875828  34.266399  173.468857       NaN
# 2018-01-05   91.542892   1.330920  17.801348  39.941090  174.315063       NaN
# 2018-01-08   92.423103   1.330920  17.726862  41.032375  175.161224       NaN
# 2018-01-09  105.626419   1.307973  17.577900  40.159348  176.007431       NaN
# ...                ...        ...        ...        ...         ...       ...
# 2022-10-06  164.830475   4.080000  32.000000  31.250000  138.000000  9.022879
# 2022-10-07  165.322495   4.000000  31.250000  31.250000  138.000000  8.779016
# 2022-10-10  162.862335   3.920000  29.500000  31.500000  137.000000  8.096204
# 2022-10-11  163.354370   3.940000  30.750000  31.250000  136.000000  7.998660
# 2022-10-12  160.894211   3.940000  32.000000  31.250000  137.500000  7.949887
#
# ...

# %%
df['CHAYO.BK'].notnull()
# Out:
# Date
# 2018-01-03    False
# 2018-01-04    False
# 2018-01-05    False
# 2018-01-08    False
# 2018-01-09    False
#               ...
# 2022-10-06     True
# 2022-10-07     True
# 2022-10-10     True
# 2022-10-11     True
# 2022-10-12     True
# Name: CHAYO.BK, Length: 1162, dtype: bool

# %%
df.loc[df['CHAYO.BK'].notnull()]
# for research we will use Adj Close
# Out:
#              AEONTS.BK  AMANAH.BK     ASK.BK     BAY.BK      BBL.BK  CHAYO.BK  \
# Date
# 2018-03-22  158.879730   1.210045  17.494516  37.103745  172.622650  1.598439
# 2018-03-23  155.358841   1.233167  17.336908  36.667233  170.930313  1.931448
# 2018-03-26  160.200058   1.225460  17.258104  36.448971  169.237900  1.953648
# 2018-03-27  165.041260   1.240874  17.258104  36.448971  170.930313  1.820444
# 2018-03-28  164.161026   1.225460  17.258104  35.794193  170.930313  1.798244
# ...                ...        ...        ...        ...         ...       ...
# 2022-10-06  164.830475   4.080000  32.000000  31.250000  138.000000  9.022879
# 2022-10-07  165.322495   4.000000  31.250000  31.250000  138.000000  8.779016
# 2022-10-10  162.862335   3.920000  29.500000  31.500000  137.000000  8.096204
# 2022-10-11  163.354370   3.940000  30.750000  31.250000  136.000000  7.998660
# 2022-10-12  160.894211   3.940000  32.000000  31.250000  137.500000  7.949887
#
# ...

# %%
df.loc[~df.isnull().sum(1).astype(bool)].iloc[0]
# Out:
# AEONTS.BK    186.226227
# AMANAH.BK      6.150000
# ASK.BK        45.000000
# BAY.BK        34.115036
# BBL.BK       133.027374
# CHAYO.BK      12.388167
# JMT.BK        80.720932
# KBANK.BK     156.978470
# KKP.BK        67.920967
# KTC.BK        59.250000
# MICRO.BK       7.270288
# MTC.BK        49.602150
# NCAP.BK        8.809120
# S11.BK         6.025000
# SAK.BK         9.377556
# SAWAD.BK      52.916512
# SCB.BK        80.318840
# THANI.BK       4.380000
# TIDLOR.BK     34.324184
# TISCO.BK      93.278137
# TK.BK         11.700000
# TTB.BK         1.271492
# Name: 2022-04-20 00:00:00, dtype: float64

# %% [markdown]
# # we will see data not have null at 2022-04-20 that cannot use for predict

# %% [markdown]
# ~ is tilde is meaning invert in binary number

# %%
df.loc[~df.isnull().sum(1).astype(bool)]
# reutrn without null
# Out:
#              AEONTS.BK  AMANAH.BK  ASK.BK     BAY.BK      BBL.BK   CHAYO.BK  \
# Date
# 2022-04-20  186.226227       6.15   45.00  34.115036  133.027374  12.388167
# 2022-04-27  182.346512       5.55   43.50  33.383999  129.565689  12.583258
# 2022-04-28  183.316437       5.75   43.00  33.871357  129.565689  12.680802
# 2022-04-29  186.711197       5.65   43.50  33.383999  129.071167  12.778346
# 2022-05-03  184.771317       5.30   42.00  33.383999  128.576645  12.388167
# ...                ...        ...     ...        ...         ...        ...
# 2022-10-06  164.830475       4.08   32.00  31.250000  138.000000   9.022879
# 2022-10-07  165.322495       4.00   31.25  31.250000  138.000000   8.779016
# 2022-10-10  162.862335       3.92   29.50  31.500000  137.000000   8.096204
# 2022-10-11  163.354370       3.94   30.75  31.250000  136.000000   7.998660
# 2022-10-12  160.894211       3.94   32.00  31.250000  137.500000   7.949887
#
# ...

# %%
df
# Out:
#              AEONTS.BK  AMANAH.BK     ASK.BK     BAY.BK      BBL.BK  CHAYO.BK  \
# Date
# 2018-01-03   91.102783   1.300324  17.726862  34.921165  173.468857       NaN
# 2018-01-04   91.102783   1.323272  17.875828  34.266399  173.468857       NaN
# 2018-01-05   91.542892   1.330920  17.801348  39.941090  174.315063       NaN
# 2018-01-08   92.423103   1.330920  17.726862  41.032375  175.161224       NaN
# 2018-01-09  105.626419   1.307973  17.577900  40.159348  176.007431       NaN
# ...                ...        ...        ...        ...         ...       ...
# 2022-10-06  164.830475   4.080000  32.000000  31.250000  138.000000  9.022879
# 2022-10-07  165.322495   4.000000  31.250000  31.250000  138.000000  8.779016
# 2022-10-10  162.862335   3.920000  29.500000  31.500000  137.000000  8.096204
# 2022-10-11  163.354370   3.940000  30.750000  31.250000  136.000000  7.998660
# 2022-10-12  160.894211   3.940000  32.000000  31.250000  137.500000  7.949887
#
# ...

# %%
df.isnull()
# Out:
#             AEONTS.BK  AMANAH.BK  ASK.BK  BAY.BK  BBL.BK  CHAYO.BK  JMT.BK  \
# Date
# 2018-01-03      False      False   False   False   False      True   False
# 2018-01-04      False      False   False   False   False      True   False
# 2018-01-05      False      False   False   False   False      True   False
# 2018-01-08      False      False   False   False   False      True   False
# 2018-01-09      False      False   False   False   False      True   False
# ...               ...        ...     ...     ...     ...       ...     ...
# 2022-10-06      False      False   False   False   False     False   False
# 2022-10-07      False      False   False   False   False     False   False
# 2022-10-10      False      False   False   False   False     False   False
# 2022-10-11      False      False   False   False   False     False   False
# 2022-10-12      False      False   False   False   False     False   False
#
# ...

# %%
~df.isnull()
# Out:
#             AEONTS.BK  AMANAH.BK  ASK.BK  BAY.BK  BBL.BK  CHAYO.BK  JMT.BK  \
# Date
# 2018-01-03       True       True    True    True    True     False    True
# 2018-01-04       True       True    True    True    True     False    True
# 2018-01-05       True       True    True    True    True     False    True
# 2018-01-08       True       True    True    True    True     False    True
# 2018-01-09       True       True    True    True    True     False    True
# ...               ...        ...     ...     ...     ...       ...     ...
# 2022-10-06       True       True    True    True    True      True    True
# 2022-10-07       True       True    True    True    True      True    True
# 2022-10-10       True       True    True    True    True      True    True
# 2022-10-11       True       True    True    True    True      True    True
# 2022-10-12       True       True    True    True    True      True    True
#
# ...

# %%
df.isnull().sum(1)
# Out:
# Date
# 2018-01-03    6
# 2018-01-04    6
# 2018-01-05    6
# 2018-01-08    6
# 2018-01-09    6
#              ..
# 2022-10-06    0
# 2022-10-07    0
# 2022-10-10    0
# 2022-10-11    0
# 2022-10-12    0
# Length: 1162, dtype: int64

# %%
~df.isnull().sum(1)
# bitwise problem
# Out:
# Date
# 2018-01-03   -7
# 2018-01-04   -7
# 2018-01-05   -7
# 2018-01-08   -7
# 2018-01-09   -7
#              ..
# 2022-10-06   -1
# 2022-10-07   -1
# 2022-10-10   -1
# 2022-10-11   -1
# 2022-10-12   -1
# Length: 1162, dtype: int64

# %%
~1
#bit wise deep drive to ascii code
# Out:
# -2

# %%
-1
# Out:
# -1

# %%
~2
# Out:
# -3

# %%
~df.isnull().sum(axis=0).astype(bool)
# cannot use sum axis = 0
# Out:
# AEONTS.BK     True
# AMANAH.BK     True
# ASK.BK        True
# BAY.BK        True
# BBL.BK        True
# CHAYO.BK     False
# JMT.BK        True
# KBANK.BK      True
# KKP.BK        True
# KTC.BK        True
# MICRO.BK     False
# MTC.BK        True
# NCAP.BK      False
# S11.BK        True
# SAK.BK       False
# SAWAD.BK      True
# SCB.BK       False
# THANI.BK      True
# TIDLOR.BK    False
# TISCO.BK      True
# TK.BK         True
# TTB.BK        True
# dtype: bool

# %%
~df.isnull().sum(axis=1).astype(bool).tail(20)
# this is result can use
# Out:
# Date
# 2022-09-15    True
# 2022-09-16    True
# 2022-09-19    True
# 2022-09-20    True
# 2022-09-21    True
# 2022-09-22    True
# 2022-09-23    True
# 2022-09-26    True
# 2022-09-27    True
# 2022-09-28    True
# 2022-09-29    True
# 2022-09-30    True
# 2022-10-03    True
# 2022-10-04    True
# 2022-10-05    True
# 2022-10-06    True
# 2022-10-07    True
# 2022-10-10    True
# 2022-10-11    True
# 2022-10-12    True
# dtype: bool

# %% [markdown]
# # this section command for search date have data

# %%
df.stack()
# Out:
# Date
# 2018-01-03  AEONTS.BK     91.102783
#             AMANAH.BK      1.300324
#             ASK.BK        17.726862
#             BAY.BK        34.921165
#             BBL.BK       173.468857
#                             ...
# 2022-10-12  THANI.BK       4.100000
#             TIDLOR.BK     24.900000
#             TISCO.BK      93.750000
#             TK.BK          9.050000
#             TTB.BK         1.210000
# Length: 21561, dtype: float64

# %%
df.reset_index()

# %%
df.stack().groupby(level=0).head(1)
# level 0 is date
# Out:
# Date
# 2018-01-03  AEONTS.BK     91.102783
# 2018-01-04  AEONTS.BK     91.102783
# 2018-01-05  AEONTS.BK     91.542892
# 2018-01-08  AEONTS.BK     92.423103
# 2018-01-09  AEONTS.BK    105.626419
#                             ...
# 2022-10-06  AEONTS.BK    164.830475
# 2022-10-07  AEONTS.BK    165.322495
# 2022-10-10  AEONTS.BK    162.862335
# 2022-10-11  AEONTS.BK    163.354370
# 2022-10-12  AEONTS.BK    160.894211
# Length: 1162, dtype: float64

# %%
df.stack().groupby(level=1).head(1)
# this command will return the first date have data

# groupby must use with something like this case use with head()
# Out:
# Date
# 2018-01-03  AEONTS.BK     91.102783
#             AMANAH.BK      1.300324
#             ASK.BK        17.726862
#             BAY.BK        34.921165
#             BBL.BK       173.468857
#             JMT.BK        13.089821
#             KBANK.BK     207.782562
#             KKP.BK        54.755272
#             KTC.BK        16.831442
#             MTC.BK        38.350212
#             S11.BK         5.907045
#             SAWAD.BK      51.122284
#             THANI.BK       4.233280
#             TISCO.BK      61.536510
#             TK.BK         12.529217
#             TTB.BK         2.345252
# 2018-03-22  CHAYO.BK       1.598439
# 2020-10-01  MICRO.BK       5.326630
# 2020-11-09  NCAP.BK        3.060000
# 2020-12-08  SAK.BK         8.019594
# 2021-05-10  TIDLOR.BK     42.156548
# 2022-04-20  SCB.BK        80.318840
# dtype: float64
