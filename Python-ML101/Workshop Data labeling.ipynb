# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('workshopdata-labeling.csv')

# %%
data
# Out:
#            Date Market Symbol       Market Cap     PE   PEG   PBV   BVPS  \
# 0    21/10/2021    SET    7UP    8,177,441,790  39.35  0.58  3.16   0.50
# 1    21/10/2021    SET     AH    7,629,103,258   6.88 -0.03  0.93  23.23
# 2    21/10/2021    SET     AI    5,564,992,217   9.18  1.50  2.14   3.71
# 3    21/10/2021    SET    AIT    8,252,835,880  15.22  0.24  2.82  14.18
# 4    21/10/2021    SET     AJ    8,536,000,000  14.44  0.32  1.78  10.87
# ..          ...    ...    ...              ...    ...   ...   ...    ...
# 219  21/10/2021    SET    TTB  109,183,848,275  13.36 -0.52  0.53   2.13
# 220  21/10/2021    SET     TU   99,253,762,317  12.64  0.26  1.71  12.14
# 221  21/10/2021    SET    TVO   25,269,093,281  10.40  0.20  2.50  12.49
# 222  21/10/2021    SET    VGI   54,680,902,246  49.99  6.53  3.44   1.85
# 223  21/10/2021    SET    WHA   49,922,427,828  21.92 -3.93  1.74   1.92
#
#      Dividend Yield  12M Dividend Yield  Volume Turnover
# ...

# %%
data.describe()
# Out:
#                 PE         PEG         PBV        BVPS  Dividend Yield  \
# count   193.000000  185.000000  224.000000  224.000000      179.000000
# mean     88.500518   -0.512324    3.490759   14.613616        3.054972
# std     627.518879    7.371914    6.460798   37.323462        2.779672
# min       2.930000  -85.780000    0.340000    0.180000        0.030000
# 25%      11.370000   -0.430000    1.180000    2.345000        1.325000
# 50%      19.580000    0.170000    2.080000    4.755000        2.410000
# 75%      30.970000    0.670000    4.005000   10.472500        3.965000
# max    8570.030000   22.800000   89.340000  293.320000       27.180000
#
#        12M Dividend Yield  Volume Turnover
# count          180.000000       223.000000
# mean             3.323389         0.556502
# std              2.471288         0.758762
# min              0.030000         0.010000
# 25%              1.652500         0.120000
# 50%              2.865000         0.280000
# ...

# %%
df=data.copy()

# %%
df
# Out:
#            Date Market Symbol       Market Cap     PE   PEG   PBV   BVPS  \
# 0    21/10/2021    SET    7UP    8,177,441,790  39.35  0.58  3.16   0.50
# 1    21/10/2021    SET     AH    7,629,103,258   6.88 -0.03  0.93  23.23
# 2    21/10/2021    SET     AI    5,564,992,217   9.18  1.50  2.14   3.71
# 3    21/10/2021    SET    AIT    8,252,835,880  15.22  0.24  2.82  14.18
# 4    21/10/2021    SET     AJ    8,536,000,000  14.44  0.32  1.78  10.87
# ..          ...    ...    ...              ...    ...   ...   ...    ...
# 219  21/10/2021    SET    TTB  109,183,848,275  13.36 -0.52  0.53   2.13
# 220  21/10/2021    SET     TU   99,253,762,317  12.64  0.26  1.71  12.14
# 221  21/10/2021    SET    TVO   25,269,093,281  10.40  0.20  2.50  12.49
# 222  21/10/2021    SET    VGI   54,680,902,246  49.99  6.53  3.44   1.85
# 223  21/10/2021    SET    WHA   49,922,427,828  21.92 -3.93  1.74   1.92
#
#      Dividend Yield  12M Dividend Yield  Volume Turnover
# ...

# %% [markdown]
# #  if marketcap come with string format can use this

# %%
df['Market Cap']= df['Market Cap'].apply(lambda x: x.replace(',', ''))

# %%
df['Market Cap']=df['Market Cap'].apply(lambda x: float(x))

# %%
df
# Out:
#            Date Market Symbol    Market Cap     PE   PEG   PBV   BVPS  \
# 0    21/10/2021    SET    7UP  8.177442e+09  39.35  0.58  3.16   0.50
# 1    21/10/2021    SET     AH  7.629103e+09   6.88 -0.03  0.93  23.23
# 2    21/10/2021    SET     AI  5.564992e+09   9.18  1.50  2.14   3.71
# 3    21/10/2021    SET    AIT  8.252836e+09  15.22  0.24  2.82  14.18
# 4    21/10/2021    SET     AJ  8.536000e+09  14.44  0.32  1.78  10.87
# ..          ...    ...    ...           ...    ...   ...   ...    ...
# 219  21/10/2021    SET    TTB  1.091838e+11  13.36 -0.52  0.53   2.13
# 220  21/10/2021    SET     TU  9.925376e+10  12.64  0.26  1.71  12.14
# 221  21/10/2021    SET    TVO  2.526909e+10  10.40  0.20  2.50  12.49
# 222  21/10/2021    SET    VGI  5.468090e+10  49.99  6.53  3.44   1.85
# 223  21/10/2021    SET    WHA  4.992243e+10  21.92 -3.93  1.74   1.92
#
#      Dividend Yield  12M Dividend Yield  Volume Turnover
# 0               NaN                 NaN             0.71
# ...

# %%
df['Label'] = df['Market Cap'].apply(lambda x: 3 if x > 1e10 else (2 if 2e9 < x < 1e10 else (1 if 3e8 < x <2e9 else 0)))

# %% [markdown]
# # alternative way

# %%
df['Label2']=df['Market Cap'].apply(lambda x :3 if x >  10000000000 else (2 if 2000000000 < x < 10000000000 else(1 if 30000000 <x <2000000000 else 0)))

# %%
df
# Out:
#            Date Market Symbol    Market Cap     PE   PEG   PBV   BVPS  \
# 0    21/10/2021    SET    7UP  8.177442e+09  39.35  0.58  3.16   0.50
# 1    21/10/2021    SET     AH  7.629103e+09   6.88 -0.03  0.93  23.23
# 2    21/10/2021    SET     AI  5.564992e+09   9.18  1.50  2.14   3.71
# 3    21/10/2021    SET    AIT  8.252836e+09  15.22  0.24  2.82  14.18
# 4    21/10/2021    SET     AJ  8.536000e+09  14.44  0.32  1.78  10.87
# ..          ...    ...    ...           ...    ...   ...   ...    ...
# 219  21/10/2021    SET    TTB  1.091838e+11  13.36 -0.52  0.53   2.13
# 220  21/10/2021    SET     TU  9.925376e+10  12.64  0.26  1.71  12.14
# 221  21/10/2021    SET    TVO  2.526909e+10  10.40  0.20  2.50  12.49
# 222  21/10/2021    SET    VGI  5.468090e+10  49.99  6.53  3.44   1.85
# 223  21/10/2021    SET    WHA  4.992243e+10  21.92 -3.93  1.74   1.92
#
#      Dividend Yield  12M Dividend Yield  Volume Turnover  Label
# ...

# %%
df.head(20)
# Out:
#           Date Market  Symbol    Market Cap       PE    PEG    PBV   BVPS  \
# 0   21/10/2021    SET     7UP  8.177442e+09    39.35   0.58   3.16   0.50
# 1   21/10/2021    SET      AH  7.629103e+09     6.88  -0.03   0.93  23.23
# 2   21/10/2021    SET      AI  5.564992e+09     9.18   1.50   2.14   3.71
# 3   21/10/2021    SET     AIT  8.252836e+09    15.22   0.24   2.82  14.18
# 4   21/10/2021    SET      AJ  8.536000e+09    14.44   0.32   1.78  10.87
# 5   21/10/2021    SET     ALT  3.057014e+09  1514.10 -15.30   1.70   1.59
# 6   21/10/2021    SET  AMANAH  5.075409e+09    16.24   0.86   3.22   1.52
# 7   21/10/2021    SET    ANAN  5.332800e+09    22.93  -0.05   0.34   4.69
# 8   21/10/2021    SET    APCS  3.563999e+09    15.26   0.03   1.89   2.86
# 9   21/10/2021    SET   APURE  8.049530e+09    24.01   0.24   4.25   2.04
# 10  21/10/2021    SET      AS  8.453303e+09    22.03   0.22  14.76   1.35
# 11  21/10/2021    SET   ASIAN  1.302540e+10    14.14   0.14   3.51   4.56
# ...

# %%
df[df['Label']==1]
# Out:
# Empty DataFrame
# Columns: [Date, Market, Symbol, Market Cap, PE, PEG, PBV, BVPS, Dividend Yield, 12M Dividend Yield, Volume Turnover, Label]
# Index: []

# %%
df['PE Range'] = df['PE'].apply(lambda x: 'PE<10' if x < 10 else ('PE 10-20' if 10 < x < 20 else ('PE 20-50' if 20 < x < 50 else('PE>50'if x>50 else 0))))

# %%
df
# Out:
#            Date Market Symbol    Market Cap     PE   PEG   PBV   BVPS  \
# 0    21/10/2021    SET    7UP  8.177442e+09  39.35  0.58  3.16   0.50
# 1    21/10/2021    SET     AH  7.629103e+09   6.88 -0.03  0.93  23.23
# 2    21/10/2021    SET     AI  5.564992e+09   9.18  1.50  2.14   3.71
# 3    21/10/2021    SET    AIT  8.252836e+09  15.22  0.24  2.82  14.18
# 4    21/10/2021    SET     AJ  8.536000e+09  14.44  0.32  1.78  10.87
# ..          ...    ...    ...           ...    ...   ...   ...    ...
# 219  21/10/2021    SET    TTB  1.091838e+11  13.36 -0.52  0.53   2.13
# 220  21/10/2021    SET     TU  9.925376e+10  12.64  0.26  1.71  12.14
# 221  21/10/2021    SET    TVO  2.526909e+10  10.40  0.20  2.50  12.49
# 222  21/10/2021    SET    VGI  5.468090e+10  49.99  6.53  3.44   1.85
# 223  21/10/2021    SET    WHA  4.992243e+10  21.92 -3.93  1.74   1.92
#
#      Dividend Yield  12M Dividend Yield  Volume Turnover  Label  PE Range
# ...

# %%
df[df['PE Range']=='PE>50']
# Out:
#            Date Market  Symbol    Market Cap       PE    PEG    PBV   BVPS  \
# 5    21/10/2021    SET     ALT  3.057014e+09  1514.10 -15.30   1.70   1.59
# 20   21/10/2021    SET    CCET  1.329147e+10    62.48   0.73   0.77   3.49
# 23   21/10/2021    SET   CHAYO  1.106243e+10    65.88   2.98   4.72   2.76
# 42   21/10/2021    SET     JTS  4.503665e+10   605.27   2.43  89.34   0.71
# 64   21/10/2021    SET     NVD  3.948516e+09   146.41  -1.00   0.88   3.26
# 70   21/10/2021    SET   PYLON  3.374430e+09    54.76  -0.69   3.50   1.29
# 77   21/10/2021    SET   SABUY  1.129156e+10    83.57    NaN   7.24   1.52
# 83   21/10/2021    SET  SEAFCO  3.387862e+09   333.86  -3.44   2.08   2.20
# 115  21/10/2021    SET    UNIQ  7.350911e+09   274.19  -2.88   0.91   7.45
# 117  21/10/2021    SET      UV  8.297761e+09  8570.03 -85.78   0.83   5.25
# 122  21/10/2021    SET     XPG  2.973748e+10   729.50 -13.28  11.26   0.60
# ...

# %%
# find dividend
~df['Dividend Yield'].isnull()
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 219     True
# 220     True
# 221     True
# 222     True
# 223     True
# Name: Dividend Yield, Length: 224, dtype: bool

# %%
df['Dividend'] = ~df['Dividend Yield'].isnull()

# %%
df
# Out:
#            Date Market Symbol    Market Cap     PE   PEG   PBV   BVPS  \
# 0    21/10/2021    SET    7UP  8.177442e+09  39.35  0.58  3.16   0.50
# 1    21/10/2021    SET     AH  7.629103e+09   6.88 -0.03  0.93  23.23
# 2    21/10/2021    SET     AI  5.564992e+09   9.18  1.50  2.14   3.71
# 3    21/10/2021    SET    AIT  8.252836e+09  15.22  0.24  2.82  14.18
# 4    21/10/2021    SET     AJ  8.536000e+09  14.44  0.32  1.78  10.87
# ..          ...    ...    ...           ...    ...   ...   ...    ...
# 219  21/10/2021    SET    TTB  1.091838e+11  13.36 -0.52  0.53   2.13
# 220  21/10/2021    SET     TU  9.925376e+10  12.64  0.26  1.71  12.14
# 221  21/10/2021    SET    TVO  2.526909e+10  10.40  0.20  2.50  12.49
# 222  21/10/2021    SET    VGI  5.468090e+10  49.99  6.53  3.44   1.85
# 223  21/10/2021    SET    WHA  4.992243e+10  21.92 -3.93  1.74   1.92
#
#      Dividend Yield  12M Dividend Yield  Volume Turnover  Label  PE Range  \
# ...
