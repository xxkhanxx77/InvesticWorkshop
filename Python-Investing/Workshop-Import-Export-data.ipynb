# %%
pip install yfinance
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import yfinance as yf

# %%
start = '2021-01-01'
end = '2022-01-01'

# %%
data = yf.download('TSLA', start=start, end=end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  239.820007  248.163330  239.063339  243.256668  243.256668
# 2021-01-05  241.220001  246.946671  239.733337  245.036667  245.036667
# 2021-01-06  252.830002  258.000000  249.699997  251.993332  251.993332
# 2021-01-07  259.209991  272.329987  258.399994  272.013336  272.013336
# 2021-01-08  285.333344  294.829987  279.463318  293.339996  293.339996
# ...                ...         ...         ...         ...         ...
# 2021-12-27  357.890015  372.333344  356.906677  364.646667  364.646667
# 2021-12-28  369.829987  373.000000  359.473328  362.823334  362.823334
# 2021-12-29  366.213318  368.000000  354.713318  362.063324  362.063324
# 2021-12-30  353.776672  365.183319  351.049988  356.779999  356.779999
# 2021-12-31  357.813324  360.666656  351.529999  352.260010  352.260010
#
#                Volume
# Date
# 2021-01-04  145914600
# 2021-01-05   96735600
# 2021-01-06  134100000
# ...

# %%
SET = yf.download('TDEX.BK',start='2019-01-01',end='2021-07-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
SET
# Out:
#              Open   High    Low  Close  Adj Close   Volume
# Date
# 2019-01-02  10.45  10.49  10.42  10.46      10.46    99700
# 2019-01-03  10.50  10.50  10.35  10.36      10.36   455700
# 2019-01-04  10.36  10.46  10.32  10.45      10.45   271000
# 2019-01-07  10.50  10.61  10.50  10.61      10.61   186400
# 2019-01-08  10.62  10.62  10.58  10.59      10.59    38500
# ...           ...    ...    ...    ...        ...      ...
# 2021-06-24   9.46   9.46   9.36   9.43       9.43  1300900
# 2021-06-25   9.44   9.48   9.40   9.44       9.44   318400
# 2021-06-28   9.42   9.42   9.35   9.39       9.39   395800
# 2021-06-29   9.38   9.46   9.38   9.45       9.45   748000
# 2021-06-30   9.46   9.47   9.40   9.40       9.40   255100
#
# [605 rows x 6 columns]

# %%
dataset = SET

# %%
dataset.head()
# Out:
#              Open   High    Low  Close  Adj Close  Volume
# Date
# 2019-01-02  10.45  10.49  10.42  10.46      10.46   99700
# 2019-01-03  10.50  10.50  10.35  10.36      10.36  455700
# 2019-01-04  10.36  10.46  10.32  10.45      10.45  271000
# 2019-01-07  10.50  10.61  10.50  10.61      10.61  186400
# 2019-01-08  10.62  10.62  10.58  10.59      10.59   38500

# %%
data.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-12-27  357.890015  372.333344  356.906677  364.646667  364.646667
# 2021-12-28  369.829987  373.000000  359.473328  362.823334  362.823334
# 2021-12-29  366.213318  368.000000  354.713318  362.063324  362.063324
# 2021-12-30  353.776672  365.183319  351.049988  356.779999  356.779999
# 2021-12-31  357.813324  360.666656  351.529999  352.260010  352.260010
#
#               Volume
# Date
# 2021-12-27  71145900
# 2021-12-28  60324000
# 2021-12-29  56154000
# 2021-12-30  47040900
# 2021-12-31  40733700

# %%
dataset.tail()
# Out:
#             Open  High   Low  Close  Adj Close   Volume
# Date
# 2021-06-24  9.46  9.46  9.36   9.43       9.43  1300900
# 2021-06-25  9.44  9.48  9.40   9.44       9.44   318400
# 2021-06-28  9.42  9.42  9.35   9.39       9.39   395800
# 2021-06-29  9.38  9.46  9.38   9.45       9.45   748000
# 2021-06-30  9.46  9.47  9.40   9.40       9.40   255100

# %%
data.asfreq('W-MON')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  239.820007  248.163330  239.063339  243.256668  243.256668
# 2021-01-11  283.133331  284.809998  267.873322  270.396667  270.396667
# 2021-01-18         NaN         NaN         NaN         NaN         NaN
# 2021-01-25  285.000000  300.133331  279.606659  293.600006  293.600006
# 2021-02-01  271.429993  280.666656  265.186676  279.936676  279.936676
# 2021-02-08  289.890015  292.589996  284.916656  287.806671  287.806671
# 2021-02-15         NaN         NaN         NaN         NaN         NaN
# 2021-02-22  254.213333  256.166656  236.733337  238.166672  238.166672
# 2021-03-01  230.036667  239.666672  228.350006  239.476669  239.476669
# 2021-03-08  200.183334  206.710007  186.263336  187.666672  187.666672
# 2021-03-15  231.363327  237.726669  228.013336  235.979996  235.979996
# 2021-03-22  228.196671  233.206665  222.916672  223.333328  223.333328
# ...

# %%
data.asfreq('W-MON').pct_change()
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2021-01-04       NaN       NaN       NaN       NaN        NaN       NaN
# 2021-01-11  0.180608  0.147672  0.120512  0.111569   0.111569  0.219239
# 2021-01-18  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 2021-01-25  0.006593  0.053802  0.043802  0.085812   0.085812 -0.305695
# 2021-02-01 -0.047614 -0.064860 -0.051572 -0.046537  -0.046537 -0.383306
# 2021-02-08  0.068010  0.042482  0.074400  0.028113   0.028113 -0.205963
# 2021-02-15  0.000000  0.000000  0.000000  0.000000   0.000000  0.000000
# 2021-02-22 -0.123070 -0.124486 -0.169114 -0.172477  -0.172477  0.848540
# 2021-03-01 -0.095104 -0.064411 -0.035413  0.005500   0.005500 -0.271896
# 2021-03-08 -0.129776 -0.137510 -0.184308 -0.216347  -0.216347  0.908410
# 2021-03-15  0.155757  0.150049  0.224145  0.257442   0.257442 -0.433534
# 2021-03-22 -0.013687 -0.019013 -0.022352 -0.053592  -0.053592  0.346903
# ...

# %%
dataset.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dataset.Close.pct_change().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
dataset.Close.pct_change(30).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stock=yf.download("MSFT AAPL",start=start,end=end)
stock
# Out:
# [*********************100%***********************]  2 of 2 completed
#              Adj Close                   Close                    High  \
#                   AAPL        MSFT        AAPL        MSFT        AAPL
# Date
# 2021-01-04  127.679985  213.342010  129.410004  217.690002  133.610001
# 2021-01-05  129.258606  213.547821  131.009995  217.899994  131.740005
# 2021-01-06  124.907555  208.010666  126.599998  212.250000  131.050003
# 2021-01-07  129.169800  213.930023  130.919998  218.289993  131.630005
# 2021-01-08  130.284714  215.233444  132.050003  219.619995  132.630005
# ...                ...         ...         ...         ...         ...
# 2021-12-27  179.016129  338.423340  180.330002  342.450012  180.419998
# 2021-12-28  177.983688  337.237457  179.289993  341.250000  181.330002
# 2021-12-29  178.073029  337.929260  179.380005  341.950012  180.630005
# 2021-12-30  176.901611  335.330139  178.199997  339.320007  180.570007
# ...

# %%
a = stock.stack(level=1)

# %%
a
# Out:
#                   Adj Close       Close        High         Low        Open  \
# Date
# 2021-01-04 AAPL  127.679985  129.410004  133.610001  126.760002  133.520004
#            MSFT  213.342010  217.690002  223.000000  214.809998  222.529999
# 2021-01-05 AAPL  129.258606  131.009995  131.740005  128.429993  128.889999
#            MSFT  213.547821  217.899994  218.520004  215.699997  217.259995
# 2021-01-06 AAPL  124.907555  126.599998  131.050003  126.379997  127.720001
# ...                     ...         ...         ...         ...         ...
# 2021-12-29 MSFT  337.929260  341.950012  344.299988  339.679993  341.299988
# 2021-12-30 AAPL  176.901611  178.199997  180.570007  178.089996  179.470001
#            MSFT  335.330139  339.320007  343.130005  338.820007  341.910004
# 2021-12-31 AAPL  176.276215  177.570007  179.229996  177.259995  178.089996
#            MSFT  332.365448  336.320007  339.359985  335.850006  338.510010
#
#                     Volume
# Date
# ...

# %%
# this stage will clean data 
a.reset_index()
a.reset_index().set_index('Date').rename(columns={'level1':'BIGTECH'})
# Out:
#            level_1   Adj Close       Close        High         Low  \
# Date
# 2021-01-04    AAPL  127.679985  129.410004  133.610001  126.760002
# 2021-01-04    MSFT  213.342010  217.690002  223.000000  214.809998
# 2021-01-05    AAPL  129.258606  131.009995  131.740005  128.429993
# 2021-01-05    MSFT  213.547821  217.899994  218.520004  215.699997
# 2021-01-06    AAPL  124.907555  126.599998  131.050003  126.379997
# ...            ...         ...         ...         ...         ...
# 2021-12-29    MSFT  337.929260  341.950012  344.299988  339.679993
# 2021-12-30    AAPL  176.901611  178.199997  180.570007  178.089996
# 2021-12-30    MSFT  335.330139  339.320007  343.130005  338.820007
# 2021-12-31    AAPL  176.276215  177.570007  179.229996  177.259995
# 2021-12-31    MSFT  332.365448  336.320007  339.359985  335.850006
#
#                   Open     Volume
# Date
# 2021-01-04  133.520004  143301900
# 2021-01-04  222.529999   37130100
# 2021-01-05  128.889999   97664900
# ...

# %%
#filter to close price in stock
filter_bigtech_stock = a.reset_index().set_index('Date').rename(columns={'level_1':'BIGTECH'})
filter_bigtech_stock.loc[:,['BIGTECH','Close']]
# Out:
#            BIGTECH       Close
# Date
# 2021-01-04    AAPL  129.410004
# 2021-01-04    MSFT  217.690002
# 2021-01-05    AAPL  131.009995
# 2021-01-05    MSFT  217.899994
# 2021-01-06    AAPL  126.599998
# ...            ...         ...
# 2021-12-29    MSFT  341.950012
# 2021-12-30    AAPL  178.199997
# 2021-12-30    MSFT  339.320007
# 2021-12-31    AAPL  177.570007
# 2021-12-31    MSFT  336.320007
#
# [504 rows x 2 columns]

# %%
stock_clean = a.reset_index().set_index('Date').rename(columns={'level_1':'stock'})
# clean stock name to value in dataframe and add index name as stock
stock_clean
# Out:
#            stock   Adj Close       Close        High         Low        Open  \
# Date
# 2021-01-04  AAPL  127.679985  129.410004  133.610001  126.760002  133.520004
# 2021-01-04  MSFT  213.342010  217.690002  223.000000  214.809998  222.529999
# 2021-01-05  AAPL  129.258606  131.009995  131.740005  128.429993  128.889999
# 2021-01-05  MSFT  213.547821  217.899994  218.520004  215.699997  217.259995
# 2021-01-06  AAPL  124.907555  126.599998  131.050003  126.379997  127.720001
# ...          ...         ...         ...         ...         ...         ...
# 2021-12-29  MSFT  337.929260  341.950012  344.299988  339.679993  341.299988
# 2021-12-30  AAPL  176.901611  178.199997  180.570007  178.089996  179.470001
# 2021-12-30  MSFT  335.330139  339.320007  343.130005  338.820007  341.910004
# 2021-12-31  AAPL  176.276215  177.570007  179.229996  177.259995  178.089996
# 2021-12-31  MSFT  332.365448  336.320007  339.359985  335.850006  338.510010
#
#                Volume
# Date
# ...

# %%
# this section will test import and export file

# %%
# !pip install google
# !pip install google-api-core
# !pip install google.colab
# Out:
# ...
#   Using cached google-colab-1.0.0.tar.gz (72 kB)
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached google_auth-1.4.2-py2.py3-none-any.whl (64 kB)
# ...
#   Using cached ipykernel-4.6.1-py3-none-any.whl (104 kB)
# ...
#   Using cached ipython-5.5.0-py3-none-any.whl (758 kB)
# ...
#   Using cached notebook-5.2.2-py2.py3-none-any.whl (8.0 MB)
# ...
#   Using cached six-1.12.0-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached pandas-0.24.2.tar.gz (11.8 MB)
#   Preparing metadata (setup.py) ... -^C
# anceled
# ERROR: Operation cancelled by user

# %%
pwd
# Out:
# '/Users/admin/Desktop/hobbies/investic-quantative/Untitled Folder'

# %%
tesla_stock=pd.read_csv('/Users/admin/Untitled Folder/tesla.csv')
tesla_excel=pd.read_excel('/Users/admin/Untitled Folder/tesla.xlsx')

# %%
tesla_stock
# Out:
#      Unnamed: 0        Date         Open         High          Low  \
# 0             0  2021-01-04   719.460022   744.489990   717.190002
# 1             1  2021-01-05   723.659973   740.840027   719.200012
# 2             2  2021-01-06   758.489990   774.000000   749.099976
# 3             3  2021-01-07   777.630005   816.989990   775.200012
# 4             4  2021-01-08   856.000000   884.489990   838.390015
# ..          ...         ...          ...          ...          ...
# 247         247  2021-12-27  1073.670044  1117.000000  1070.719971
# 248         248  2021-12-28  1109.489990  1119.000000  1078.420044
# 249         249  2021-12-29  1098.640015  1104.000000  1064.140015
# 250         250  2021-12-30  1061.329956  1095.550049  1053.150024
# 251         251  2021-12-31  1073.439941  1082.000000  1054.589966
#
#            Close    Adj Close    Volume
# 0     729.770020   729.770020  48638200
# 1     735.109985   735.109985  32245200
# ...

# %%
tesla_excel
# Out:
#           Date         Open         High          Low        Close  \
# 0   2021-01-04   719.460022   744.489990   717.190002   729.770020
# 1   2021-01-05   723.659973   740.840027   719.200012   735.109985
# 2   2021-01-06   758.489990   774.000000   749.099976   755.979980
# 3   2021-01-07   777.630005   816.989990   775.200012   816.039978
# 4   2021-01-08   856.000000   884.489990   838.390015   880.020020
# ..         ...          ...          ...          ...          ...
# 247 2021-12-27  1073.670044  1117.000000  1070.719971  1093.939941
# 248 2021-12-28  1109.489990  1119.000000  1078.420044  1088.469971
# 249 2021-12-29  1098.640015  1104.000000  1064.140015  1086.189941
# 250 2021-12-30  1061.329956  1095.550049  1053.150024  1070.339966
# 251 2021-12-31  1073.439941  1082.000000  1054.589966  1056.780029
#
#        Adj Close    Volume
# 0     729.770020  48638200
# 1     735.109985  32245200
# 2     755.979980  44700000
# 3     816.039978  51498900
# ...

# %%
tesla_excel.to_csv('tesla.csv')

# %%
#price condition 

data_price_condition = yf.download('BTC-USD', start='2021-01-01', end='2022-05-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data_price_condition
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-01-01  28994.009766  29600.626953  28803.585938  29374.152344
# 2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 2021-01-03  32129.408203  34608.558594  32052.316406  32782.023438
# 2021-01-04  32810.949219  33440.218750  28722.755859  31971.914062
# 2021-01-05  31977.041016  34437.589844  30221.187500  33992.429688
# ...                  ...           ...           ...           ...
# 2022-04-26  40448.421875  40713.890625  37884.984375  38117.460938
# 2022-04-27  38120.300781  39397.917969  37997.312500  39241.121094
# 2022-04-28  39241.429688  40269.464844  38941.421875  39773.828125
# 2022-04-29  39768.617188  39887.269531  38235.535156  38609.824219
# 2022-04-30  38605.859375  38771.210938  37697.941406  37714.875000
#
#                Adj Close       Volume
# Date
# 2021-01-01  29374.152344  40730301359
# 2021-01-02  32127.267578  67865420765
# ...

# %%
df_price_condition = data_price_condition.copy()

# %%
df_price_condition['Return']= df_price_condition['Close'].pct_change()

# %%
df_price_condition
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-01-01  28994.009766  29600.626953  28803.585938  29374.152344
# 2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 2021-01-03  32129.408203  34608.558594  32052.316406  32782.023438
# 2021-01-04  32810.949219  33440.218750  28722.755859  31971.914062
# 2021-01-05  31977.041016  34437.589844  30221.187500  33992.429688
# ...                  ...           ...           ...           ...
# 2022-04-26  40448.421875  40713.890625  37884.984375  38117.460938
# 2022-04-27  38120.300781  39397.917969  37997.312500  39241.121094
# 2022-04-28  39241.429688  40269.464844  38941.421875  39773.828125
# 2022-04-29  39768.617188  39887.269531  38235.535156  38609.824219
# 2022-04-30  38605.859375  38771.210938  37697.941406  37714.875000
#
#                Adj Close       Volume    Return
# Date
# 2021-01-01  29374.152344  40730301359       NaN
# 2021-01-02  32127.267578  67865420765  0.093726
# ...

# %%
df_price_condition[df_price_condition['Close']>60000]
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-03-13  57343.371094  61683.863281  56217.972656  61243.085938
# 2021-04-11  59846.230469  60790.554688  59289.796875  60204.964844
# 2021-04-13  59890.019531  63742.285156  59869.957031  63503.457031
# 2021-04-14  63523.753906  64863.097656  61554.796875  63109.695312
# 2021-04-15  63075.195312  63821.671875  62208.964844  63314.011719
# 2021-04-16  63258.503906  63594.722656  60222.531250  61572.789062
# 2021-04-17  61529.921875  62572.175781  60361.351562  60683.820312
# 2021-10-15  57345.902344  62757.128906  56868.144531  61593.949219
# 2021-10-16  61609.527344  62274.476562  60206.121094  60892.179688
# 2021-10-17  60887.652344  61645.523438  59164.468750  61553.617188
# 2021-10-18  61548.804688  62614.660156  60012.757812  62026.078125
# 2021-10-19  62043.164062  64434.535156  61622.933594  64261.992188
# 2021-10-20  64284.585938  66930.390625  63610.675781  65992.835938
# ...

# %%
df_price_condition[df_price_condition.Return>0]
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 2021-01-03  32129.408203  34608.558594  32052.316406  32782.023438
# 2021-01-05  31977.041016  34437.589844  30221.187500  33992.429688
# 2021-01-06  34013.613281  36879.699219  33514.035156  36824.363281
# 2021-01-07  36833.875000  40180.367188  36491.191406  39371.042969
# ...                  ...           ...           ...           ...
# 2022-04-18  39721.203125  40986.320312  38696.191406  40826.214844
# 2022-04-19  40828.175781  41672.960938  40618.632812  41502.750000
# 2022-04-25  39472.605469  40491.753906  38338.378906  40458.308594
# 2022-04-27  38120.300781  39397.917969  37997.312500  39241.121094
# 2022-04-28  39241.429688  40269.464844  38941.421875  39773.828125
#
#                Adj Close       Volume    Return
# Date
# 2021-01-02  32127.267578  67865420765  0.093726
# 2021-01-03  32782.023438  78665235202  0.020380
# ...

# %%
def checkGainLoss(df_return):
    if df_return > 0:
        return 'Gain'
    elif pd.isna(df_return):
        return 'Unknown'
    else:
        return 'Loss'

# %%
df_price_condition['result']=df_price_condition.Return.map(checkGainLoss)

# %%
df_price_condition
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-01-01  28994.009766  29600.626953  28803.585938  29374.152344
# 2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 2021-01-03  32129.408203  34608.558594  32052.316406  32782.023438
# 2021-01-04  32810.949219  33440.218750  28722.755859  31971.914062
# 2021-01-05  31977.041016  34437.589844  30221.187500  33992.429688
# ...                  ...           ...           ...           ...
# 2022-04-26  40448.421875  40713.890625  37884.984375  38117.460938
# 2022-04-27  38120.300781  39397.917969  37997.312500  39241.121094
# 2022-04-28  39241.429688  40269.464844  38941.421875  39773.828125
# 2022-04-29  39768.617188  39887.269531  38235.535156  38609.824219
# 2022-04-30  38605.859375  38771.210938  37697.941406  37714.875000
#
#                Adj Close       Volume    Return   result
# Date
# 2021-01-01  29374.152344  40730301359       NaN  Unknown
# ...

# %%
dfx=df_price_condition.dropna(inplace=True)

# %%
dfx

# %%
df_price_condition
# Out:
#                     Open          High           Low         Close  \
# Date
# 2021-01-02  29376.455078  33155.117188  29091.181641  32127.267578
# 2021-01-03  32129.408203  34608.558594  32052.316406  32782.023438
# 2021-01-04  32810.949219  33440.218750  28722.755859  31971.914062
# 2021-01-05  31977.041016  34437.589844  30221.187500  33992.429688
# 2021-01-06  34013.613281  36879.699219  33514.035156  36824.363281
# ...                  ...           ...           ...           ...
# 2022-04-26  40448.421875  40713.890625  37884.984375  38117.460938
# 2022-04-27  38120.300781  39397.917969  37997.312500  39241.121094
# 2022-04-28  39241.429688  40269.464844  38941.421875  39773.828125
# 2022-04-29  39768.617188  39887.269531  38235.535156  38609.824219
# 2022-04-30  38605.859375  38771.210938  37697.941406  37714.875000
#
#                Adj Close       Volume    Return result
# Date
# 2021-01-02  32127.267578  67865420765  0.093726   Gain
# ...

# %%
## resample

# %%
tesla_weekly = data.resample('W-FRI').agg({'Open':'first',
                                    'High':'max',
                                    'Low':'min',
                                    'Close':'last',
                                    'Volume':'sum'})

# %%
tesla_weekly
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2021-01-08  239.820007  294.829987  239.063339  293.339996  756413400
# 2021-01-15  283.133331  289.333344  267.873322  275.386658  626786100
# 2021-01-22  279.266663  286.500000  276.206665  282.213318  274861500
# 2021-01-29  285.000000  300.133331  260.033325  264.510010  459023400
# 2021-02-05  271.429993  293.500000  265.186676  284.076660  307381200
# 2021-02-12  289.890015  292.589996  261.776672  272.040009  350779800
# 2021-02-19  272.666656  273.666656  254.003326  260.433319  248142600
# 2021-02-26  254.213333  256.166656  206.333328  225.166672  662270100
# 2021-03-05  230.036667  240.369995  179.830002  199.316666  709177200
# 2021-03-12  200.183334  239.283340  186.263336  231.243332  749261100
# 2021-03-19  231.363327  237.726669  208.206665  218.289993  534067800
# 2021-03-26  228.196671  233.206665  199.963333  206.236664  530631000
# ...

# %%
tesla_weekly.Close.pct_change(10).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
tesla_monthly = data.resample('BM').agg({'Open':'first',
                                      'High':'max',
                                      'Low':'min',
                                      'Close':'last',
                                      'Volume':'sum'})

# %%
tesla_monthly
# Out:
#                   Open        High         Low       Close      Volume
# Date
# 2021-01-29  239.820007  300.133331  239.063339  264.510010  2117084400
# 2021-02-26  271.429993  293.500000  206.333328  225.166672  1568573700
# 2021-03-31  230.036667  240.369995  179.830002  222.643326  2827357200
# 2021-04-30  229.456665  260.263336  219.806671  236.479996  2035619100
# 2021-05-31  234.600006  235.333328  182.326660  208.406662  1875527400
# 2021-06-30  209.266663  232.539993  190.406662  226.566666  1559765700
# 2021-07-30  227.973328  233.333328  206.820007  229.066666  1345349400
# 2021-08-31  233.333328  246.796661  216.279999  245.240005  1143974700
# 2021-09-30  244.693329  266.333344  236.283340  258.493347  1170513900
# 2021-10-29  259.466675  371.736664  254.529999  371.333344  1586803800
# 2021-11-30  381.666656  414.496674  326.200012  381.586670  1947334500
# 2021-12-31  386.899994  390.946655  295.373322  352.260010  1530167700

# %%
tesla_monthly.Close.pct_change(1).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df_everyday = data.resample('D').last()

# %%
df_everyday
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  239.820007  248.163330  239.063339  243.256668  243.256668
# 2021-01-05  241.220001  246.946671  239.733337  245.036667  245.036667
# 2021-01-06  252.830002  258.000000  249.699997  251.993332  251.993332
# 2021-01-07  259.209991  272.329987  258.399994  272.013336  272.013336
# 2021-01-08  285.333344  294.829987  279.463318  293.339996  293.339996
# ...                ...         ...         ...         ...         ...
# 2021-12-27  357.890015  372.333344  356.906677  364.646667  364.646667
# 2021-12-28  369.829987  373.000000  359.473328  362.823334  362.823334
# 2021-12-29  366.213318  368.000000  354.713318  362.063324  362.063324
# 2021-12-30  353.776672  365.183319  351.049988  356.779999  356.779999
# 2021-12-31  357.813324  360.666656  351.529999  352.260010  352.260010
#
#                  Volume
# Date
# 2021-01-04  145914600.0
# 2021-01-05   96735600.0
# 2021-01-06  134100000.0
# ...

# %%
df_everyday.fillna(method='ffill', inplace=True)

# %%
df_everyday
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  239.820007  248.163330  239.063339  243.256668  243.256668
# 2021-01-05  241.220001  246.946671  239.733337  245.036667  245.036667
# 2021-01-06  252.830002  258.000000  249.699997  251.993332  251.993332
# 2021-01-07  259.209991  272.329987  258.399994  272.013336  272.013336
# 2021-01-08  285.333344  294.829987  279.463318  293.339996  293.339996
# ...                ...         ...         ...         ...         ...
# 2021-12-27  357.890015  372.333344  356.906677  364.646667  364.646667
# 2021-12-28  369.829987  373.000000  359.473328  362.823334  362.823334
# 2021-12-29  366.213318  368.000000  354.713318  362.063324  362.063324
# 2021-12-30  353.776672  365.183319  351.049988  356.779999  356.779999
# 2021-12-31  357.813324  360.666656  351.529999  352.260010  352.260010
#
#                  Volume
# Date
# 2021-01-04  145914600.0
# 2021-01-05   96735600.0
# 2021-01-06  134100000.0
# ...

# %%
df_businessday = df_everyday.resample('B').last()

# %%
df_businessday
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-01-04  239.820007  248.163330  239.063339  243.256668  243.256668
# 2021-01-05  241.220001  246.946671  239.733337  245.036667  245.036667
# 2021-01-06  252.830002  258.000000  249.699997  251.993332  251.993332
# 2021-01-07  259.209991  272.329987  258.399994  272.013336  272.013336
# 2021-01-08  285.333344  294.829987  279.463318  293.339996  293.339996
# ...                ...         ...         ...         ...         ...
# 2021-12-27  357.890015  372.333344  356.906677  364.646667  364.646667
# 2021-12-28  369.829987  373.000000  359.473328  362.823334  362.823334
# 2021-12-29  366.213318  368.000000  354.713318  362.063324  362.063324
# 2021-12-30  353.776672  365.183319  351.049988  356.779999  356.779999
# 2021-12-31  357.813324  360.666656  351.529999  352.260010  352.260010
#
#                  Volume
# Date
# 2021-01-04  145914600.0
# 2021-01-05   96735600.0
# 2021-01-06  134100000.0
# ...

# %%
tesla_weekly.head()
# Out:
#                   Open        High         Low       Close     Volume
# Date
# 2021-01-08  239.820007  294.829987  239.063339  293.339996  756413400
# 2021-01-15  283.133331  289.333344  267.873322  275.386658  626786100
# 2021-01-22  279.266663  286.500000  276.206665  282.213318  274861500
# 2021-01-29  285.000000  300.133331  260.033325  264.510010  459023400
# 2021-02-05  271.429993  293.500000  265.186676  284.076660  307381200

# %%
tesla_weekly['next_week_closing'] = tesla_weekly['Close'].shift(-1)
tesla_weekly.tail()
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2021-12-03  366.996674  390.946655  333.403320  338.323334  373556700
# 2021-12-10  333.836670  357.459991  316.833344  339.010010  298756800
# 2021-12-17  333.696655  335.000000  303.013336  310.856659  407779800
# 2021-12-24  303.566681  357.660004  295.373322  355.666656  314345400
# 2021-12-31  357.890015  373.000000  351.049988  352.260010  275398500
#
#             next_week_closing
# Date
# 2021-12-03         339.010010
# 2021-12-10         310.856659
# 2021-12-17         355.666656
# 2021-12-24         352.260010
# 2021-12-31                NaN

# %%
tesla_weekly['weekly_return'] = tesla_weekly['Close'].pct_change(-1)
tesla_weekly.head()
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 2021-01-08  239.820007  294.829987  239.063339  293.339996  756413400
# 2021-01-15  283.133331  289.333344  267.873322  275.386658  626786100
# 2021-01-22  279.266663  286.500000  276.206665  282.213318  274861500
# 2021-01-29  285.000000  300.133331  260.033325  264.510010  459023400
# 2021-02-05  271.429993  293.500000  265.186676  284.076660  307381200
#
#             next_week_closing  weekly_return
# Date
# 2021-01-08         275.386658       0.065193
# 2021-01-15         282.213318      -0.024190
# 2021-01-22         264.510010       0.066929
# 2021-01-29         284.076660      -0.068878
# 2021-02-05         272.040009       0.044246
